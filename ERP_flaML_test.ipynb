# %%
#!pip install "flaml[autogen]"
from flaml import autogen

assistant = autogen.AssistantAgent("assistant")
user_proxy = autogen.UserProxyAgent("user_proxy")
user_proxy.initiate_chat(
    assistant,
    message="Show me the YTD gain of 10 largest technology companies as of today.",
)
# This initiates an automated chat between the two agents to solve the task
# Out:
# user_proxy (to assistant):
#
# Show me the YTD gain of 10 largest technology companies as of today.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 assistant = autogen.AssistantAgent("assistant")
#       5 user_proxy = autogen.UserProxyAgent("user_proxy")
# ----> 6 user_proxy.initiate_chat(
#       7     assistant,
#       8     message="Show me the YTD gain of 10 largest technology companies as of today.",
#       9 )
#
# File d:\python_Anaconda_install\Lib\site-packages\flaml\autogen\agentchat\conversable_agent.py:523, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, **context)
#     509 """Initiate a chat with the recipient agent.
#     510
#     511 Reset the consecutive auto reply counter.
#    (...)
#     520         "message" needs to be provided if the `generate_init_message` method is not overridden.
#     521 """
#     522 self._prepare_chat(recipient, clear_history)
# --> 523 self.send(self.generate_init_message(**context), recipient, silent=silent)
#
# File d:\python_Anaconda_install\Lib\site-packages\flaml\autogen\agentchat\conversable_agent.py:326, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#     324 valid = self._append_oai_message(message, "assistant", recipient)
#     325 if valid:
# --> 326     recipient.receive(message, self, request_reply, silent)
#     327 else:
#     328     raise ValueError(
#     329         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#     330     )
#
# File d:\python_Anaconda_install\Lib\site-packages\flaml\autogen\agentchat\conversable_agent.py:454, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#     452 if request_reply is False or request_reply is None and self.reply_at_receive[sender] is False:
#     453     return
# --> 454 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#     455 if reply is not None:
#     456     self.send(reply, sender, silent=silent)
#
# File d:\python_Anaconda_install\Lib\site-packages\flaml\autogen\agentchat\conversable_agent.py:766, in ConversableAgent.generate_reply(self, messages, sender, exclude)
#     764     continue
#     765 if self._match_trigger(reply_func_tuple["trigger"], sender):
# --> 766     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#     767     if final:
#     768         return reply
#
# File d:\python_Anaconda_install\Lib\site-packages\flaml\autogen\agentchat\conversable_agent.py:598, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#     595     messages = self._oai_messages[sender]
#     597 # TODO: #1143 handle token limit exceeded error
# --> 598 response = oai.ChatCompletion.create(
#     599     context=messages[-1].pop("context", None), messages=self._oai_system_message + messages, **llm_config
#     600 )
#     601 return True, oai.ChatCompletion.extract_text_or_function_call(response)[0]
#
# File d:\python_Anaconda_install\Lib\site-packages\flaml\autogen\oai\completion.py:804, in Completion.create(cls, context, use_cache, config_list, filter_func, raise_on_ratelimit_or_timeout, allow_format_str_template, **config)
#     802 with diskcache.Cache(cls.cache_path) as cls._cache:
#     803     cls.set_cache(seed)
# --> 804     return cls._get_response(params, raise_on_ratelimit_or_timeout=raise_on_ratelimit_or_timeout)
#
# File d:\python_Anaconda_install\Lib\site-packages\flaml\autogen\oai\completion.py:211, in Completion._get_response(cls, config, raise_on_ratelimit_or_timeout, use_cache)
#     209         response = openai_completion.create(**config)
#     210     else:
# --> 211         response = openai_completion.create(request_timeout=request_timeout, **config)
#     212 except (
#     213     ServiceUnavailableError,
#     214     APIConnectionError,
#     215 ):
#     216     # transient error
#     217     logger.info(f"retrying in {cls.retry_time} seconds...", exc_info=1)
#
# File d:\python_Anaconda_install\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File d:\python_Anaconda_install\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:149, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#     141         timeout,
#     142         stream,
#     143         headers,
#     144         request_timeout,
#     145         typed_api_type,
#     146         requestor,
#     147         url,
#     148         params,
# --> 149     ) = cls.__prepare_create_request(
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
#     153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#    (...)
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#
# File d:\python_Anaconda_install\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:106, in EngineAPIResource.__prepare_create_request(cls, api_key, api_base, api_type, api_version, organization, **params)
#     103 elif timeout == 0:
#     104     params["timeout"] = MAX_TIMEOUT
# --> 106 requestor = api_requestor.APIRequestor(
#     107     api_key,
#     108     api_base=api_base,
#     109     api_type=api_type,
#     110     api_version=api_version,
#     111     organization=organization,
#     112 )
#     113 url = cls.class_url(engine, api_type, api_version)
#     114 return (
#     115     deployment_id,
#     116     engine,
#    (...)
#     124     params,
#     125 )
#
# File d:\python_Anaconda_install\Lib\site-packages\openai\api_requestor.py:138, in APIRequestor.__init__(self, key, api_base, api_type, api_version, organization)
#     129 def __init__(
#     130     self,
#     131     key=None,
#    (...)
#     135     organization=None,
#     136 ):
#     137     self.api_base = api_base or openai.api_base
# --> 138     self.api_key = key or util.default_api_key()
#     139     self.api_type = (
#     140         ApiType.from_str(api_type)
#     141         if api_type
#     142         else ApiType.from_str(openai.api_type)
#     143     )
#     144     self.api_version = api_version or openai.api_version
#
# File d:\python_Anaconda_install\Lib\site-packages\openai\util.py:186, in default_api_key()
#     184     return openai.api_key
#     185 else:
# --> 186     raise openai.error.AuthenticationError(
#     187         "No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://platform.openai.com/account/api-keys for details."
#     188     )
#
# AuthenticationError: No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://platform.openai.com/account/api-keys for details.
